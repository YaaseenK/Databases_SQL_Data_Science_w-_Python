# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
#
# # Connect to Db2 database on Cloud using Python
#
#
# Estimated time needed: **15** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Import the ibm_db Python library
# * Enter the database connection credentials
# * Create the database connection
# * Close the database connection

# %% [markdown]
# __Note:__ Please follow the instructions given in the first Lab of this course to Create a database service instance of Db2 on Cloud and retrieve your database Service Credentials.
#
# ## Import the `ibm_db` Python library
#
# The `ibm_db` [API ](https://pypi.python.org/pypi/ibm_db/) provides a variety of useful Python functions for accessing and manipulating data in an IBM® data server database, including functions for connecting to a database, preparing and issuing SQL statements, fetching rows from result sets, calling stored procedures, committing and rolling back transactions, handling errors, and retrieving metadata.
#
#
# We first import the ibm_db library into our Python Application
#
# Execute the following cells by clicking within it and then
# press `Shift` and `Enter` keys simultaneously
#
# The following required modules are pre-installed in the Skills Network Labs environment. However if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you may need to install these libraries by removing the `#` sign before `!pip` in the code cell below.

# %%
# These libraries are pre-installed in SN Labs. If running in another environment please uncomment lines below to install them:
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# Ensure we don't load_ext with sqlalchemy>=1.4 (incompadible)
# !pip uninstall sqlalchemy==1.4 -y && pip install sqlalchemy==1.3.24
# !pip install ipython-sql
# Out:
# Collecting ibm_db==3.1.0
#   Downloading ibm_db-3.1.0.tar.gz (797 kB)
#      ---------------------------------------- 0.0/797.3 kB ? eta -:--:--
#       --------------------------------------- 10.2/797.3 kB ? eta -:--:--
#      - ----------------------------------- 41.0/797.3 kB 487.6 kB/s eta 0:00:02
#      --------------- ---------------------- 327.7/797.3 kB 2.9 MB/s eta 0:00:01
#      -------------------------------------  788.5/797.3 kB 5.5 MB/s eta 0:00:01
#      -------------------------------------  788.5/797.3 kB 5.5 MB/s eta 0:00:01
#      -------------------------------------- 797.3/797.3 kB 3.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ibm_db_sa==0.3.3
#   Downloading ibm_db_sa-0.3.3.tar.gz (24 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting sqlalchemy>=0.7.3 (from ibm_db_sa==0.3.3)
#   Using cached sqlalchemy-2.0.39-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=0.7.3->ibm_db_sa==0.3.3)
#   Using cached greenlet-3.1.1-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy>=0.7.3->ibm_db_sa==0.3.3)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached sqlalchemy-2.0.39-cp311-cp311-win_amd64.whl (2.1 MB)
# Using cached greenlet-3.1.1-cp311-cp311-win_amd64.whl (298 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Building wheels for collected packages: ibm_db, ibm_db_sa
#   Building wheel for ibm_db (pyproject.toml): started
#   Building wheel for ibm_db (pyproject.toml): finished with status 'error'
#   Building wheel for ibm_db_sa (pyproject.toml): started
#   Building wheel for ibm_db_sa (pyproject.toml): finished with status 'done'
#   Created wheel for ibm_db_sa: filename=ibm_db_sa-0.3.3-py3-none-any.whl size=27548 sha256=6341d573480178c6603f0e9a59a25855ecd8553a6e6a3a6af39ed78c4dd0c6b7
#   Stored in directory: c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\cb\af\47\1cdbd4797d6c6cbc611c5aa48a53df475cb46fe8b0d3856193
# Successfully built ibm_db_sa
# Failed to build ibm_db
#   error: subprocess-exited-with-error
#
#   × Building wheel for ibm_db (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [1154 lines of output]
#       Detected 64-bit Python
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\dist.py:760: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: Apache Software License
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       creating build\lib.win-amd64-cpython-311
#       copying ibm_db_dbi.py -> build\lib.win-amd64-cpython-311
#       copying testfunctions.py -> build\lib.win-amd64-cpython-311
#       copying tests.py -> build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\certs
#       copying certs\__init__.py -> build\lib.win-amd64-cpython-311\certs
#       creating build\lib.win-amd64-cpython-311\clidriver
#       copying clidriver\__init__.py -> build\lib.win-amd64-cpython-311\clidriver
#       creating build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_000_PrepareDb.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_001_ConnDb.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_002_ConnDbUncatalogedConn.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_003_NumAffectedRows.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_004_ConnWrongUserPwd.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_005_ConnBadUserBadPwd.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_006_ConnPassingOpts.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_007_pConnPassingOpts.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_008_ColumnInfo.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_010_UpdateRowCount.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_011_DeleteRowCount.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_012_KeysetDrivenCursorSelect01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_013_KeysetDrivenCursorSelect02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_014_KeysetDrivenCursorNegativeRow.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_015_InsertDeleteRowCount_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_016_InsertDeleteRowCount_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_017_selectRowcountPrefetchSTMTOpt.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_018_selectRowcountPrefetchSetOpt.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_019_selectRowcountPrefetchPrepOpt.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_020_RollbackDelete.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_021_CommitDelete.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_022_RollbackInsert.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_023_ColumnPrivileges.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_024_ForeignKeys.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_025_PrimaryKeys.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_030_Result.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_031_ResultIndexPosition.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_032_ResultIndexName.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_033_ResultOutSequenceColumn.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_034_FetchAssoc.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_035_FetchRow_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_036_FetchRow_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_037_FetchRowIndexPos.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_038_FetchRowIndexPosNested_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_039_FetchRowIndexPosNested_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_03a_ResultNonExistCol.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_040_FetchTuple.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_041_FetchTupleMany_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_042_FetchTupleMany_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_043_FetchTupleMany_03.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_044_FetchTupleMany_04.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_045_FetchTupleBinaryData_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_046_FetchTupleMany_05.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_047_FetchTupleMany_06.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_048_FetchTupleBinaryData_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_049_InsertNoneParam.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_050_AutocommitStatus.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_051_SetAutocommit_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_052_SetAutocommit_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_053_AttrThruConn.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_054_CursorType.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_060_Tables_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_061_Tables_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_062_Tables_03.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_063_Tables_04.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_064_Tables_05.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_065_FilterTableName.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_066_TableObjects.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_070_Close.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_071_CloseSuccess.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_080_ConnWrongDbAlias.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_081_ConnWrongUser.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_082_ConnWrongPwd.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_090_ConnmsgWrongDbAlias.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_091_ConnmsgWrongUser.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_092_ConnmsgWrongPwd.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_100_SelectDeleteInsertFieldCount.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_101_InsertDeleteFieldCount.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_102_NumFieldsSelect_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_103_NumFieldsSelect_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_110_FieldNum.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_111_FieldNumAddCol.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_112_FieldNumDiffCaseColNames.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_113_DateTest.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_114_NumericTest_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_115_NumericTest_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_116_ConnActive.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_120_FieldName.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_121_FieldNameAddCol.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_122_FieldNameDiffCaseColNames.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_123_FieldNamePos_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_124_FieldNamePos_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_125_FieldNamePos_03.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_130_PrepExecuteSelectStmt.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_131_PrepareExecuteSelectStatementParams.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_132_ExecuteStatementArrayMultipleParams.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_133_ExecuteLongInputParams.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_140_BindParamSelectStmt.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_141_BindParamSelectStmtMultipleParams_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_142_BindParamSelectStmtMultipleParams_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_143_BindParamInsertStmtNoneParam.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_144_BindParamInsertStmtPARAM_FILE.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_145_BindRetrieveNoneEmptyString.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_146_CallSPINAndOUTParams.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_147_PrepareWithWrongType.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_148_CallSPDiffBindPattern_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_150_FetchAssocSelect_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_151_FetchAssocSelect_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_152_FetchAssocSelect_03.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_153_FetchAssocSelect_04.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_154_AllFetches.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_155_FetchAssocSelect_05.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_156_FetchAssocNestedSelects_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_157a_FetchAssocWithoutScrollableCursorErr.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_157b_FetchAssocScrollableCursor_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_157_FetchAssocScrollableCursor_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_158_FetchAssocNestedSelects_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_159a_FetchAssocSeveralRows_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_159_FetchAssocSeveralRows_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_160_FetchBoth.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_161_FetchBothNestedSelects_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_162_FetchBothNestedSelects_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_180_StmtErrMsg.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_190_ColumnsTable_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_191_ColumnsTable_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_195_InsertRetrieveXMLData_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_196_InsertRetrieveXMLData_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_197_StatisticsIndexes.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_200_MultipleRsltsetsUniformColDefs.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_201_MultipleRsltsetsDiffColDefs.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_210_FieldDisplaySize_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_211_FieldDisplaySize_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_212_FieldDisplaySize_03.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_213_FieldDisplaySize_04.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_220_PersistentConn.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_221_100PersistentConns.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_230_FieldTypePos.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_231_FieldTypeName.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_232_FieldTypePosName.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_240_FieldWidthPosName_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_241_FieldWidthPosName_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_250_FreeResult_01.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_251_FreeResult_02.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_260_FetchTupleMany_07.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_261_FetchObjectAccess.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_264_InsertRetrieveBIGINTTypeColumn.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_265_NoAffectedRows.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_300_ServerInfo.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_310_ClientInfo.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_311_InsertSelectDeleteNumLiterals.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_52949_TestSPIntVarcharXml.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_6528_ScopingProblemBindParam.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_6561_InsertNULLValues.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_6755_ExtraNULLChar_ResultCLOBCol.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_6792_FieldTypeRetStrDatetimeTimestamp.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_booleanInsertSelect.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_bool_callproc.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_checkBooleanType.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_createdbNX.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_createDropDB.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_currentschema.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_cursortype.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_decfloat.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_decimal.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_err_executemany.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_execute_many.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_InsertRetrieveDateTimeTypeColumn.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_recreateDB.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_setgetOption.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_SPInOutBlob.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_SPInOutZero.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_trusted_context_connect.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_trusted_context_pconnect.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\test_warn.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       copying ibm_db_tests\__init__.py -> build\lib.win-amd64-cpython-311\ibm_db_tests
#       running egg_info
#       writing ibm_db.egg-info\PKG-INFO
#       writing dependency_links to ibm_db.egg-info\dependency_links.txt
#       writing top-level names to ibm_db.egg-info\top_level.txt
#       reading manifest file 'ibm_db.egg-info\SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       warning: no files found matching '*.png' under directory 'ibm_db_tests'
#       warning: no files found matching '*.jpg' under directory 'ibm_db_tests'
#       warning: no files found matching '*' under directory 'ibm_db_dlls'
#       warning: no previously-included files found matching 'config.py'
#       adding license file 'LICENSE'
#       writing manifest file 'ibm_db.egg-info\SOURCES.txt'
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.bin' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bin' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bin' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bin' to be distributed and are
#               already explicitly excluding 'clidriver.bin' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.bin.icc64' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bin.icc64' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bin.icc64' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bin.icc64' to be distributed and are
#               already explicitly excluding 'clidriver.bin.icc64' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.bin.icc64.c.icc' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bin.icc64.c.icc' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bin.icc64.c.icc' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bin.icc64.c.icc' to be distributed and are
#               already explicitly excluding 'clidriver.bin.icc64.c.icc' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.bin.icc64.c.icc.icclib' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bin.icc64.c.icc.icclib' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bin.icc64.c.icc.icclib' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bin.icc64.c.icc.icclib' to be distributed and are
#               already explicitly excluding 'clidriver.bin.icc64.c.icc.icclib' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.bin.icc64.n.icc' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bin.icc64.n.icc' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bin.icc64.n.icc' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bin.icc64.n.icc' to be distributed and are
#               already explicitly excluding 'clidriver.bin.icc64.n.icc' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.bin.icc64.n.icc.icclib' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bin.icc64.n.icc.icclib' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bin.icc64.n.icc.icclib' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bin.icc64.n.icc.icclib' to be distributed and are
#               already explicitly excluding 'clidriver.bin.icc64.n.icc.icclib' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.bnd' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.bnd' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.bnd' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.bnd' to be distributed and are
#               already explicitly excluding 'clidriver.bnd' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.cfg' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.cfg' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.cfg' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.cfg' to be distributed and are
#               already explicitly excluding 'clidriver.cfg' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.conv.alt' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.conv.alt' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.conv.alt' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.conv.alt' to be distributed and are
#               already explicitly excluding 'clidriver.conv.alt' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.conv.ms' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.conv.ms' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.conv.ms' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.conv.ms' to be distributed and are
#               already explicitly excluding 'clidriver.conv.ms' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
#               ********************************************************************************
#
#       !!
#         check.warn(importable)
#       C:\Users\River\AppData\Local\Temp\pip-build-env-eechwhtq\overlay\Lib\site-packages\setuptools\command\build_py.py:212: _Warning: Package 'clidriver.db2' is absent from the `packages` configuration.
#       !!
#
#               ********************************************************************************
#               ############################
#               # Package would be ignored #
#               ############################
#               Python recognizes 'clidriver.db2' as an importable package[^1],
#               but it is absent from setuptools' `packages` configuration.
#
#               This leads to an ambiguous overall configuration. If you want to distribute this
#               package, please make sure that 'clidriver.db2' is explicitly added
#               to the `packages` configuration field.
#
#               Alternatively, you can also rely on setuptools' discovery methods
#               (for example by using `find_namespace_packages(...)`/`find_namespace:`
#               instead of `find_packages(...)`/`find:`).
#
#               You can read more about "package discovery" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/package_discovery.html
#
#               If you don't want 'clidriver.db2' to be distributed and are
#               already explicitly excluding 'clidriver.db2' via
#               `find_namespace_packages(...)/find_namespace` or `find_packages(...)/find`,
#               you can try to use `exclude_package_data`, or `include-package-data=False` in
#               combination with a more fine grained `package-data` configuration.
#
#               You can read more about "package data files" on setuptools documentation page:
#
#               - https://setuptools.pypa.io/en/latest/userguide/datafiles.html
#
#
#               [^1]: For Python, any directory (with suitable naming) can be imported,
#                     even if it does not contain any `.py` files.
#                     On the other hand, currently there is no concept of package data
#                     directory, all directories are treated like packages.
# ...
#       copying clidriver\conv\ms\1390ucs2.cnv -> build\lib.win-amd64-cpython-311\clidriver\conv\ms
#       copying clidriver\conv\ms\1399ucs2.cnv -> build\lib.win-amd64-cpython-311\clidriver\conv\ms
#       copying clidriver\conv\ms\5039ucs2.cnv -> build\lib.win-amd64-cpython-311\clidriver\conv\ms
#       copying clidriver\conv\ms\ucs20943.cnv -> build\lib.win-amd64-cpython-311\clidriver\conv\ms
#       creating build\lib.win-amd64-cpython-311\clidriver\db2
#       copying clidriver\db2\db2diag.log -> build\lib.win-amd64-cpython-311\clidriver\db2
#       creating build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sql.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlca.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlcli.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlcli1.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlda.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlenv.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlext.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlstate.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlsystm.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqltypes.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlucode.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       copying clidriver\include\sqlunx.h -> build\lib.win-amd64-cpython-311\clidriver\include
#       creating build\lib.win-amd64-cpython-311\clidriver\lib
#       copying clidriver\lib\db2app64.lib -> build\lib.win-amd64-cpython-311\clidriver\lib
#       copying clidriver\lib\db2cli64.lib -> build\lib.win-amd64-cpython-311\clidriver\lib
#       creating build\lib.win-amd64-cpython-311\clidriver\license
#       copying clidriver\license\odbc_REDIST.txt -> build\lib.win-amd64-cpython-311\clidriver\license
#       copying clidriver\license\odbc_notices.rtf -> build\lib.win-amd64-cpython-311\clidriver\license
#       creating build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_br.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_cn.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_cz.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_de.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_el.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_en.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_es.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_fr.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_in.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_it.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_jp.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_kr.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_lt.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_pl.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_ru.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_sl.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_tr.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       copying clidriver\license\Windows\odbc_LI_tw.rtf -> build\lib.win-amd64-cpython-311\clidriver\license\Windows
#       creating build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2adm.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2admh.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2caem.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2cklog.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2cli.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2clia1.lst -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2clias.lst -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2clih.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2clit.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2clp.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2clp2.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2fodc.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2sql.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2sqlh.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2stt.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       copying clidriver\msg\en_US\db2supp.mo -> build\lib.win-amd64-cpython-311\clidriver\msg\en_US
#       creating build\lib.win-amd64-cpython-311\clidriver\properties\version
#       copying clidriver\properties\version\ibm.com_IBM_Data_Server_Driver_for_ODBC_and_CLI-11.5.0.swidtag -> build\lib.win-amd64-cpython-311\clidriver\properties\version
#       creating build\lib.win-amd64-cpython-311\clidriver\scripts
#       copying clidriver\scripts\setenv.bat -> build\lib.win-amd64-cpython-311\clidriver\scripts
#       copying clidriver\scripts\testconnection.bat -> build\lib.win-amd64-cpython-311\clidriver\scripts
#       creating build\lib.win-amd64-cpython-311\clidriver\security\plugin\IBM\client
#       copying clidriver\security\plugin\IBM\client\IBMIAMauth64.dll -> build\lib.win-amd64-cpython-311\clidriver\security\plugin\IBM\client
#       running build_ext
#       building 'ibm_db' extension
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for ibm_db
# ERROR: Could not build wheels for ibm_db, which is required to install pyproject.toml-based projects
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\River\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Found existing installation: SQLAlchemy 2.0.39
# Uninstalling SQLAlchemy-2.0.39:
#   Successfully uninstalled SQLAlchemy-2.0.39
# Collecting sqlalchemy==1.3.24
#   Downloading SQLAlchemy-1.3.24.tar.gz (6.4 MB)
#      ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.4 MB ? eta -:--:--
#      ---------------------------------------- 0.0/6.4 MB 330.3 kB/s eta 0:00:20
#       --------------------------------------- 0.1/6.4 MB 939.4 kB/s eta 0:00:07
#      --- ------------------------------------ 0.6/6.4 MB 3.9 MB/s eta 0:00:02
#      ------- -------------------------------- 1.2/6.4 MB 6.5 MB/s eta 0:00:01
#      --------- ------------------------------ 1.5/6.4 MB 6.4 MB/s eta 0:00:01
#      ------------- -------------------------- 2.1/6.4 MB 7.4 MB/s eta 0:00:01
#      --------------------- ------------------ 3.5/6.4 MB 10.6 MB/s eta 0:00:01
#      --------------------------- ------------ 4.3/6.4 MB 11.1 MB/s eta 0:00:01
#      ------------------------------- -------- 5.0/6.4 MB 11.3 MB/s eta 0:00:01
#      ----------------------------------- ---- 5.7/6.4 MB 11.7 MB/s eta 0:00:01
#      ---------------------------------------  6.3/6.4 MB 11.9 MB/s eta 0:00:01
#      ---------------------------------------- 6.4/6.4 MB 11.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (pyproject.toml): started
#   Building wheel for sqlalchemy (pyproject.toml): finished with status 'done'
#   Created wheel for sqlalchemy: filename=sqlalchemy-1.3.24-cp311-cp311-win_amd64.whl size=1203363 sha256=2fec9d065755f0bfaf83d0c9f5889e2353b840057ffdd6ee80aebe030a3ec88f
#   Stored in directory: c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local\pip\cache\wheels\27\e3\c5\7ba1f3cf983a93b35c849e97fd51a82aa7adf440641a2f690b
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
# Successfully installed sqlalchemy-1.3.24
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.3.24 which is incompatible.
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\River\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipython-sql in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (3.15.1)
# Requirement already satisfied: ipython in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (9.0.1)
# Collecting sqlalchemy>=2.0 (from ipython-sql)
#   Using cached sqlalchemy-2.0.39-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: sqlparse in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (0.5.3)
# Requirement already satisfied: six in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.12.2)
# Requirement already satisfied: colorama in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prettytable->ipython-sql) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data->ipython->ipython-sql) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data->ipython->ipython-sql) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\river\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data->ipython->ipython-sql) (0.2.3)
# Using cached sqlalchemy-2.0.39-cp311-cp311-win_amd64.whl (2.1 MB)
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.3.24
#     Uninstalling SQLAlchemy-1.3.24:
#       Successfully uninstalled SQLAlchemy-1.3.24
# Successfully installed sqlalchemy-2.0.39
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\River\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install --force-reinstall ibm_db ibm_db_sa
import ibm_db
# Out:
# Collecting ibm_db
#   Using cached ibm_db-3.2.6-cp311-cp311-win_amd64.whl.metadata (34 kB)
# Collecting ibm_db_sa
#   Using cached ibm_db_sa-0.4.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting sqlalchemy>=0.7.3 (from ibm_db_sa)
#   Using cached sqlalchemy-2.0.39-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy>=0.7.3->ibm_db_sa)
#   Using cached greenlet-3.1.1-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy>=0.7.3->ibm_db_sa)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Using cached ibm_db-3.2.6-cp311-cp311-win_amd64.whl (28.0 MB)
# Using cached ibm_db_sa-0.4.1-py3-none-any.whl (31 kB)
# Using cached sqlalchemy-2.0.39-cp311-cp311-win_amd64.whl (2.1 MB)
# Using cached greenlet-3.1.1-cp311-cp311-win_amd64.whl (298 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: ibm_db, typing-extensions, greenlet, sqlalchemy, ibm_db_sa
#   Attempting uninstall: ibm_db
#     Found existing installation: ibm_db 3.2.6
#     Uninstalling ibm_db-3.2.6:
#       Successfully uninstalled ibm_db-3.2.6
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 3.1.1
#     Uninstalling greenlet-3.1.1:
#       Successfully uninstalled greenlet-3.1.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.39
#     Uninstalling SQLAlchemy-2.0.39:
#       Successfully uninstalled SQLAlchemy-2.0.39
#   Attempting uninstall: ibm_db_sa
#     Found existing installation: ibm_db_sa 0.4.1
#     Uninstalling ibm_db_sa-0.4.1:
#       Successfully uninstalled ibm_db_sa-0.4.1
# Successfully installed greenlet-3.1.1 ibm_db-3.2.6 ibm_db_sa-0.4.1 sqlalchemy-2.0.39 typing-extensions-4.12.2
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: C:\Users\River\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 get_ipython().system('pip install --force-reinstall ibm_db ibm_db_sa')
# ----> 2 import ibm_db
#
# ImportError: DLL load failed while importing ibm_db: The specified module could not be found.

# %% [markdown]
# When the command above completes, the `ibm_db` library is loaded in your notebook.
#
#
# ## Identify the database connection credentials
#
# Connecting to dashDB or DB2 database requires the following information:
# * Driver Name
# * Database name
# * Host DNS name or IP address
# * Host port
# * Connection protocol
# * User ID (or username)
# * User Password
#
#
#
# __Notice:__ To obtain credentials please refer to the instructions given in the first Lab of this course
#
# Now enter your database credentials below and execute the cell with `Shift` + `Enter`

# %%
#Replace the placeholder values with your actual Db2 hostname, username, and password:
dsn_hostname = "YourDb2Hostname" # e.g.: "54a2f15b-5c0f-46df-8954-7e38e612c2bd.c1ogj3sd0tgtu0lqde00.databases.appdomain.cloud"
dsn_uid = "YourDb2Username"        # e.g. "abc12345"
dsn_pwd = "YoueDb2Password"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_port = "YourPort"                # e.g. "32733" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"
dsn_security = "SSL"              #i.e. "SSL"

# %% [markdown]
# ## Create the DB2 database connection
#
# Ibm_db API uses the IBM Data Server Driver for ODBC and CLI APIs to connect to IBM DB2 and Informix.
#
#
# Lets build the dsn connection string using the credentials you entered above

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create the dsn connection string
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};"
    "SECURITY={7};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd,dsn_security)

#print the connection string to check correct values are specified
print(dsn)

# %% [markdown]
# Now establish the connection to the database

# %%
#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create database connection

try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )

# %% [markdown]
# Congratulations if you were able to connect successfuly. Otherwise check the error and try again.

# %%
#Retrieve Metadata for the Database Server
server = ibm_db.server_info(conn)

print ("DBMS_NAME: ", server.DBMS_NAME)
print ("DBMS_VER:  ", server.DBMS_VER)
print ("DB_NAME:   ", server.DB_NAME)

# %%
#Retrieve Metadata for the Database Client / Driver
client = ibm_db.client_info(conn)

print ("DRIVER_NAME:          ", client.DRIVER_NAME) 
print ("DRIVER_VER:           ", client.DRIVER_VER)
print ("DATA_SOURCE_NAME:     ", client.DATA_SOURCE_NAME)
print ("DRIVER_ODBC_VER:      ", client.DRIVER_ODBC_VER)
print ("ODBC_VER:             ", client.ODBC_VER)
print ("ODBC_SQL_CONFORMANCE: ", client.ODBC_SQL_CONFORMANCE)
print ("APPL_CODEPAGE:        ", client.APPL_CODEPAGE)
print ("CONN_CODEPAGE:        ", client.CONN_CODEPAGE)

# %% [markdown]
# ## Close the Connection
# We free all resources by closing the connection. Remember that it is always important to close connections so that we can avoid unused connections taking up resources.

# %%
ibm_db.close(conn)

# %% [markdown]
# ## Summary
#
# In this tutorial you established a connection to a DB2 database on Cloud database from a Python notebook using ibm_db API.

# %% [markdown]
# ## Author
#
# <a href="https://www.linkedin.com/in/ravahuja">Rav Ahuja</a>
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
#
# ```{toggle} ## Change Log
# ```
#
#
# ```{toggle}|  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# ```
# ```{toggle}|---|---|---|---|
# ```
# ```{toggle}| 2021-11-17  | 2.2  | Lakshmi  | Updated library  |
# ```
# ```{toggle}| 2021-07-09  | 2.1  | Malika   | Updated the connection string  |
# ```
# ```{toggle}| 2020-08-28  | 2.0  | Lavanya  |  Moved lab to course repo in GitLab  |
# ```
